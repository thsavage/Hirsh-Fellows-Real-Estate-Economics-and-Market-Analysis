# %% [markdown]
# # *Hirsh Fellows*: Real Estate Economics and Market Analysis

# %% [markdown]
# # Session 1
#
# ## Resuming the course arc: What Is the difference between finance and economics?
# ## Your goals
# ## My goals
# ## An introduction to urban economics
#
#
#
# * **Graph 0**: Supply, demand and equilibrium
#
#
#
# ## The real estate market analysis and its role in investment decision making
# * Economic analysis of a local market or of a property type: Miami-Office or Inland Empire-Industrial
# * An investment committee (IC) memorandum
#     * Large investors in CRE maintain investment committees (ICs) that approve or reject investment theses written by analysts.
#     * The effort involves both economics and finance.
#     * Judgment of analyst.
#     * Decision of the IC.
#
#
# ## The components of the market analysis
# 1. Current demand and supply conditions, as well as current capital market conditions.
# 2. Probabilistic forecasts of future rents, vacancy and cap rates, driven by employment growth and changes in capital market conditions.
#     * [CBRE Econometric Advisors (EA)](https://www.cbre-ea.com)
#     * Research arms of other large brokerages: C&W, JLL, Newmark and others
#     * Moody's REIS
#     * Bespoke analyses of consulting shops, such as GreenStreet Advisors, RCLCO and Eigen 10
#     * A comment on the 500 pound gorilla in the room
# 3. Long-term supply (delivery) from Dodge Analytics or from local broker knowledge.
#
#
# ## An update on student goals and interests

# %% [markdown]
# # An introduction to urban economics
#
# ## Populations are highly concentrated in locations that we call *cities*
# * They are not randomly or uniformly distributed over space.
# * Major cities in the U.S. comprise ~2% of total land area but comprise >40% of the population.
# * Population densities are higher in certain parts of Europe and Asia.
# * Considerable vacant space: ~56,000 Census tracts in the U.S., half of which are empty.
# * **Class Discussion**:  Why does spatial concentration exist?
#
# ## Broad drivers of spatial concentration
# * Safety of high city walls.
# * Social networks.
#
# ## Economic drivers of spatial concentration
# * The economics of scale and of agglomeration.
# * Population growth and "random" distribution.
#     * Consider the idea that a random distribution of the human population would comprise a ground state.  (Technically, uniformly distributed across land masses.)
# * U.S. population density from 1789.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('PUwmA3Q0_OE')

# %%
YouTubeVideo('lbC9-WfuOIw')

# %%
YouTubeVideo('VKbh_IrmGXM')

# %% [markdown]
# ## The economics of scale: firm size and efficient production
# * **Graph 1: The production function and varying returns to scale**
# * Increased returns to scale.
# * Efficiency improves as an enterprise gets larger.
#     * **Bigger is better** because it may be more **efficient**.
# * As size drives efficiency, it drives **the concentration of employment**.
#     * Virtuous cycle: demand for employees (workers) and increased productivity drive up wages.
#     * **Higher wages than farming and agriculture.**
#     * *Dark satanic mills* of Britain's Industrial Revolution.
# * Consider an island that produces one good that it exports for income.
# * Inputs to production are *labor* and *materials*, both abundant on the island.
#     * Abstract away from capital and land.
# * Production exhibits scale economies: output per worker is higher given the concentration of workers.
#     * Primary focus is production
#     * Division of labor: each worker focuses on one task to perfection
#     * Graph of scale economies
#     * Consider Coase's *Theory of the Firm* or a Cobb-Douglas production function: output $=f(L^\alpha, M^\beta)$, where $\alpha + \beta \le 1$.
#         * 100 factories with one worker
#         * 1 factory with 100 specialized workers
#         * At reasonable levels of production, the single factory is more efficient than the sum of 100 factories
#         * Absent anything else, however, increasing returns may run into bottlenecks and begin to experience diminshing returns
#     * **Class Discussion**: What else?

# %% [markdown]
# ## The economics of agglomeration: positive network externalities
# * Social networks *did not* begin with FaceBook.
# * The value of a social network is greater for an individual in the network as the size of the network grows.
#     * The scale of individuals: positive network effects.
#     * The value to individuals of a social network the more useful "nodes" in the network.
#     * Spill-over effects from "Friday drinks".
# * The same is true of urban clusters for both firms and individuals.
#     * Firms: lower input costs (perhaps through transportation networks) with potential productivity gains
#     * Individuals: sharing of knowledge and skills to enhance human capital, productivity and wages.
# * Agglomeration is either *pecuniary* or *technological*.
#     * **Pecuniary**: reduction to input costs without affecting the productivity of individual inputs
#     * **Technological**: increase to the productivity of individual inputs without lowering their cost
#     * **Combined**: inputs are cheaper in large cities, and they are more productive

# %% [markdown]
# ## The market analysis
# * What comprises the economic and financial analysis of a geographic market or an asset class?
# * How might we examine these components?
# * How might these components interact to help us assess an investment thesis?
#     * Consider DiPasquale and Wheaton (DW).
#     * Supply and demand in each of the four quadrants.
# * To evaluate an investment thesis, institutional investors have investment committees (IC).
#     * They are *pitched* investment proposals by individuals focused on deal flow.
#     * Based on the components of an IC memorandum, the IC votes whether or not to proceed.
#     * From the portfolio perspective, this can be both acquistions and dispositions in a larger portfolio.
# * The central focus of an IC memorandum is a market analysis, which is an economic and financial analysis that focuses on a particular geographic area or asset class or both.
#     * Acquisition of a *multifamily (MF)* portfolio in *Miami* or an *office portfolio* in *Paris*.
#     * Disposition of an *industrial portfolio* in *Leeds, U.K.* after year 7.
# * Components
#     * Current demand
#     * Near-term supply
#     * Probablistic forecasts of supply, demand and cap rates that affect rent and vacancy
# * **Class Discussion**: your market analysis
#     * Individual or teams of two?
#     * Geographic markets
#         * Gateway
#         * Secondary
#         * Tertiary
#     * Asset types
#         * Traditional: O, I, R and A (MF)
#         * Emerging:
#             * Self storage
#             * Last-mile industrial
#             * Senior living
#             * Student housing

# %% [markdown]
# # Session 2

# %% [markdown]
# ## The economics of scale and agglomeration
# ## Potential data sources

# %% [markdown]
# ## Agglomeration: further exploration of the pecuniary
# * Consider New York City with its large concentration of jobs and potential workers.
#     * Many workers offer their services to employers that specialize in finance, real estate, fashion, media or tech.
#     * Suppose an elite real estate developer wants to hire specialized and rare skill set.
#         * Is it more probable that such a person exists in NYC or a rural area?
#         * Firm search costs constitute a substantial cost and are higher in rural areas.
#         * Relocation costs from rural to urban constitute additional expenses.
#     * The ability to poach from other firms because of larger labor supply pool, thus creating more competition.
# * **Force multiplication**: as jobs become more concentrated, more firms have an economic incentive to maintain a location in an urban cluster.
#     * A rural area creates market power for the specialized worker.
#     * An urban area neutralizes that market power.
#     * And reduces the cost of employee turnover.
#     * Younger employees with more recent skills express an interest in living in large cities.
#         * FAANG: all major tech companies are creating substantial presence in urban clusters.
# * Transportation is a **critical component of urban density**, but it involves direct costs (fares and tolls) and indirect costs (time).
#     * Physical transportation of goods and workers comprises a considerable cost to production.
#     * Firms directly pay for the shipment of their products: co-location (supply and demand) reduces costs.
#     * Firms indirectly pay for their employees' transportation: public transportation infrastructure.
#     * Amazon's development of same-day delivery: co-location of supply and demand.
# * **Class discussion**: Examples?  Why the Schack Institute sits in class C space in midtown.  Will COVID-19 change the landscape?  Quite probably if it affects the amenities.

# %% [markdown]
# ## Agglomeration: further exploration of the technological
# * Technological agglomeration as the result of positive network effects: location, location, location.
# * Consider a proptech start-up that must spend considerable VC money on development for the purpose of patenting and resale.
#     * A measure of ouput that is the number of patents, which in turn drives resale.
#     * **Graph 2: Urban and Rural Production**
#     * The "Big City" generates a higher marginal product from knowledge spillovers (people and technological applications).
#     * The difficult to measure: the economics of envy rather than the economics of utility.
# * **Class discussion**: Examples?
#     * *Brooklyn Navy Yard* in NYC
#     * *Canary Wharf* in London
#     * *La Defense* in Paris
#     * Other examples beyond real estate?

# %% [markdown]
# ## Cities and the built space: considerable empirical literature supports the above
#
# * Rosenthal and Strange (2004) is a survey of economic literature up that point.
# * Henderson (1986, 2003) explores the connection between worker productivity and both own-industry and total employment in cities.
#     * As was noted earlier, such studies often find evidence of an own-industry effect for knowledge-intensive industries, in which spillovers are likely to occur.
#     * Little evidence of a total-employment effect.
# * Ciccone and Hall (1996) examines the relation between worker productivity to employment density in cities.
# * Rosenthal and Strange (2003) examines linkages between the creation of new firms to own-industry employment, on the belief that business startups are more likely to occur in areas offering agglomeration economies.
# * See also Glaeser *et al*. (1992), Jaffe *et al*. (1993) and Carlino *et al*. (2007).
# * The findings in the research literature provide considerable support showing the existence of agglomeration economies in cities, mostly of the technological type.

# %% [markdown]
# ## Another consideration of scale economies: transportation costs
# * Difficult to address: build it and they will come?
#     * Perhaps, but many transportation networks developed with urbanization
# * Useful to consider
#     * **Graph 3: Two-part pricing of transportation**
#     * Costs per unit decline by distance, but this does not address end users
#     * Last-mile logistics: global supply chains and local supply chains

# %% [markdown]
# ## Class discussion: the evolution of retail as an integration of the above
# * An example of a market study
# * Your managing director has asked you to prepare a market study of a class B retail mall in suburban Florida
#     * What would be the components of this study?
#     * How might you forecast the future?
#         * Rents
#         * Vacancy
#         * Cap rates

# %% [markdown]
# ## Potential data providers
#
# * Brokerages: CBRE, Cushman, Newmark and JLL
#     * Public market reports on rents and vacancies
#     * Cap rate surveys from their capital market groups
#     * Access to the EA data warehouse
#     * Access to Newmark data warehouse
# * Vendors: CoStar, Reonomy and RCA
#     * No access to CoStar
# * Open Source: FRED, Census and BLS
#     * https://fred.stlouisfed.org

# %%
# Via open source tools

# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import patsy
from matplotlib.colors import ListedColormap
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)

import datetime as dt
from fredapi import Fred
fred = Fred(api_key='30e6ecb242a73869e11cb35f6aa3afc3')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ten_year = fred.get_series("GS10", observation_start='1990-01-01')
one_year = fred.get_series("DGS1", observation_start='1990-01-01')
three_month = fred.get_series("DGS3MO", observation_start='1990-01-01')

ten_year.plot(color='darkblue', figsize=(8, 6))
plt.suptitle('Long Duration Rates Are Falling', fontsize=20)
plt.xlabel('Date', fontsize=16)
plt.ylabel('%', fontsize=16)
plt.axhline(3.0, color="black")
plt.axhline(1.0, color="red")

# %%
ten_year.plot(c='darkred', label='10 Year', figsize=(8, 6), )
one_year.plot(c='green', label='One Year')
three_month.plot(color='blue', label='Three Month')
plt.suptitle('Long- and Short-Rates Have Largely Decoupled', fontsize=20)
plt.legend()
plt.xlabel('Date', fontsize=16)
plt.ylabel('%', fontsize=16)
plt.axvline(dt.datetime(2008, 9, 15), color="red")

# %% [markdown]
# ## Some non-U.S. examples
#
# * ECB [link](https://sdw.ecb.europa.eu/)
# * Python library called pandaSDMX that is a functional API to the following data sources.
#
#     * Australian Bureau of Statistics (ABS)
#     * European Central Bank (ECB)
#     * Eurostat
#     * French National Institute for Statistics (INSEE)
#     * Instituto Nacional de la Estadìstica y Geografìa - INEGI (Mexico)
#     * International Monetary Fund (IMF) - SDMX Central only
#     * International Labour Organization (ILO)
#     * Italian statistics Office (ISTAT)
#     * Norges Bank (Norway)
#     * Organisation for Economic Cooperation and Development (OECD)
#     * United Nations Statistics Division (UNSD)

# %%
import requests
import io
from pandasdmx import Request

# %%
# Building blocks for the URL
entrypoint = 'https://sdw-wsrest.ecb.europa.eu/service/' # Using protocol 'https'
resource = 'data'           # The resource for data queries is always'data'
flowRef ='EXR'              # Dataflow describing the data that needs to be returned, exchange rates in this case
key = 'D.CHF.EUR.SP00.A'    # Defining the dimension values, explained below

# Define the parameters
parameters = {
    'startPeriod': '2000-01-01',  # Start date of the time series
    'endPeriod': '2020-05-01'     # End of the time series
}

# %%
# Construct the URL: https://sdw-wsrest.ecb.europa.eu/service/data/EXR/D.CHF.EUR.SP00.A
request_url = entrypoint + resource + '/'+ flowRef + '/' + key

# Make the HTTP request
response = requests.get(request_url, params=parameters)

# Check if the response returns succesfully with response code 200
print(response)

# Print the full URL
print(response.url)
# Out:
# <Response [200]>
# https://sdw-wsrest.ecb.europa.eu/service/data/EXR/D.CHF.EUR.SP00.A?startPeriod=2000-01-01&endPeriod=2020-05-01

# %%
# Print the first 1000 characters of the response
print(response.text[0:1000])
# Out:
# <?xml version="1.0" encoding="UTF-8"?><message:GenericData xmlns:message="http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message" xmlns:common="http://www.sdmx.org/resources/sdmxml/schemas/v2_1/common" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:generic="http://www.sdmx.org/resources/sdmxml/schemas/v2_1/data/generic" xsi:schemaLocation="http://www.sdmx.org/resources/sdmxml/schemas/v2_1/message https://sdw-wsrest.ecb.europa.eu:443/vocabulary/sdmx/2_1/SDMXMessage.xsd http://www.sdmx.org/resources/sdmxml/schemas/v2_1/common https://sdw-wsrest.ecb.europa.eu:443/vocabulary/sdmx/2_1/SDMXCommon.xsd http://www.sdmx.org/resources/sdmxml/schemas/v2_1/data/generic https://sdw-wsrest.ecb.europa.eu:443/vocabulary/sdmx/2_1/SDMXDataGeneric.xsd">
# <message:Header>
# <message:ID>f9594fa0-d565-44e9-9637-e3d376097b2c</message:ID>
# <message:Test>false</message:Test>
# <message:Prepared>2020-09-30T17:22:16.413+02:00</message:Prepared>
# <message:Sender id="ECB"/>
# ...

# %%
# Make the HTTP request again, now requesting for CSV format
response = requests.get(request_url, params=parameters, headers={'Accept': 'text/csv'})

# Response succesful? (Response code 200)
print(response)
# Out:
# <Response [200]>

# %%
data = pd.read_csv(io.StringIO(response.text))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5261 entries, 0 to 5260
# Data columns (total 32 columns):
# KEY                5261 non-null object
# FREQ               5261 non-null object
# CURRENCY           5261 non-null object
# CURRENCY_DENOM     5261 non-null object
# EXR_TYPE           5261 non-null object
# EXR_SUFFIX         5261 non-null object
# TIME_PERIOD        5261 non-null object
# OBS_VALUE          5200 non-null float64
# OBS_STATUS         5261 non-null object
# OBS_CONF           640 non-null object
# OBS_PRE_BREAK      0 non-null float64
# OBS_COM            0 non-null float64
# TIME_FORMAT        5261 non-null object
# BREAKS             0 non-null float64
# COLLECTION         5261 non-null object
# COMPILING_ORG      0 non-null float64
# DISS_ORG           0 non-null float64
# DOM_SER_IDS        0 non-null float64
# PUBL_ECB           0 non-null float64
# PUBL_MU            0 non-null float64
# PUBL_PUBLIC        0 non-null float64
# ...

# %%
# Create a new DataFrame called 'ts'
ts = data.filter(['TIME_PERIOD', 'OBS_VALUE'], axis=1)

# 'TIME_PERIOD' was of type 'object' (as seen in df.info). Convert it to datetime first
ts['TIME_PERIOD'] = pd.to_datetime(ts['TIME_PERIOD'])

# Set 'TIME_PERIOD' to be the index
ts = ts.set_index('TIME_PERIOD')

# Print the last 5 rows to screen
ts.tail()
# Out:
#              OBS_VALUE
# TIME_PERIOD
# 2020-04-24      1.0525
# 2020-04-27      1.0557
# 2020-04-28      1.0586
# 2020-04-29      1.0571
# 2020-04-30      1.0558

# %%
ts.plot(figsize=(8, 6), legend=False, c='darkblue')
plt.suptitle('Euro : Swiss Franc Exchange Rate', fontsize=20)
plt.title('Since the Launch of the Euro', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.ylabel('One Euro Buys', fontsize=16)
plt.axvline(dt.datetime(2008, 9, 15), color="red")

# %% [markdown]
# ## Class discussion: your market analysis

# %% [markdown]
# # Session 3

# %% [markdown]
# ## Urban spatial structure
# ## An introduction to Pareto efficiency and sources of market failure

# %% [markdown]
# ## Transportation costs: another consideration of scale economies
# * Difficult to address: build it and they will come?  (Say's "Law": supply creates its own demand.)
#     * Does mass public transportation facilitate urbanization and which came first?
#         * [The Misery Line](https://en.wikipedia.org/wiki/Northern_line) of the London Underground
#         * [The IRT](https://en.wikipedia.org/wiki/List_of_New_York_City_Subway_lines) of the New York Subway
#     * Many transportation networks developed with urbanization and not as a precursor.
#     * Older forms of transportation networks?
#
#
#
# * Useful to consider the following stylized model
#     * **Graph 3: Two-part pricing of transportation**: Price per mile versus distance, $k$
#     * Costs per unit decline by distance.
#         * How to see this?  Start at the origin and draw a line to slope.  Draw a second line further out, and note its slope is decreasing.  In this graph, the slope is the marginal cost.
#     * Last-mile logistics: global supply chains and local supply chains

# %% [markdown]
# ## Urban spatial structure
# * The built space in urban clusters.
# * All of this sounds very purposive: as if a beneign social-utility-maximizing entity designed it all.
#     * *Not true*.
#     * 1666 fire of London: Sir Christopher Wren sought to create a grid that never emerged.
#     * Napolean III knocked down most of old Paris to usher in what we see today.
#     * NYC: We will talk more about this later in the semester.

# %% [markdown]
# ## Concentric circles: an idealized urban cluster
# * **Graph 4: Concentric Circles**
# * Density is concentrated at the center and falls proportionately as one moves away from the CBD
# * The sizes of living dwellings (apartments and houses) tend to be smaller in the center and larger in the concentric circules.
#     * While building heights fall moving away from the center, dwelling sizes increase.
#     * And yet this idealizded urban cluster is not typically found in practice.
#     * Midtown Manhattan
#     * Downtown Brooklyn
#     * Long Island City
#     * London?
#     * Paris?
#     * Berlin?
# * **Class Discussion**: What is a CBD?

# %% [markdown]
# ## Mathematics as visualization
# * One can express these observations as mathematics
# * Better to focus on visualizations to make the ideas concrete
# * References:
#     * Alonso (1964)
#     * Muth (1969): parent of rational expectations
#     * Mills (1969)
#     * Wheaton (1974): parent of TWR and later CBRE's Econometric Advisors
#     * Brueckner (1987)

# %% [markdown]
# ## Basic assumptions
# > "All models are wrong, but some models are useful." *George Box*
#
# * Start simply and evaluate implications.  Include frictions once the friction-free implications are understood
#
#
# 1. All employment is in the center of the city, the "CBD".  It's an easy assumption to relax.
#
# > "It's where the banks were."  *Doug Poutasse*
#
# 2. The CBD is a point mass not an "area".
# 3. Transportation is a dense radial network from the point mass.
# 4. Identical households that are "representative agents".  (Common assumption in much of economics that allows us to avoid dealing with macro and micro at the same time.  See Box quote.)  Easy to relax by allowing households to be rich and poor
# 5. Households consume two goods: housing and everything else.  Consumption is afforded by wage income.  "Housing and bread"
#
#
# * **Graph 5: Representation of Urban Cluster**

# %% [markdown]
# ## Basic accounting
#
# * Let $x$ denote the radial distance from an employee's residence to the CBD.
#
#
#
# * $x_1 > x_2 \Rightarrow$ it is more costly for employee$_1$ to travel to work than employee$_2$.
#     * Two components: price (direct cost) and time (opportunity cost)
#
#
#
# * Let $t$ denote the per-distance cost of commuting, which implies that $x \cdot t$ is the total cost of a one-way journey.  In the U.S., this is measured as mile-dollars.  In much of Europe, this is ?
#     * $t$ also captures alternative transportation modes.  One journey on the NYC ferry system is the same as Midtown Center to Washington Square.
#     * Tim to Schack on the ferry: $0.10 \cdot 2.75 = 0.275$ mile-dollars.
#     * Tim to Boston on the Acela: $4 \cdot 200 = 800$ mile-dollars.
#
#
#
# * Let $y$ denote wage income from employment in the CBD.  Disposible income $i$ is, therefore, $y-x \cdot t$.
#     * The expression in increasing in $y$ but decreasing in both $x$ and $t$, and the effects are linear.
#
#
#
# * Consumption consists of two goods: transportation and “bread”.
#     * Bread consumption is denoted by $c$, normalized to 1.
#     * Housing consumption is denoted by $q$, but the physical units corresponding to $q$ must be chosen.
#         * Housing is complicated and varies considerably by its characteristics.  Let $p$ be a simple characteristic: rental price per square unit.
#         * Housing costs are, therefore, $q \cdot p$.
#
#
#
# * Consumer budget constraint is:
#     * $c + q \cdot p = y–x \cdot t$.
#
#
#
# * The goal of the employee is maximize her utility over $c$ and $q$ given the budget constraint.

# %% [markdown]
# ## Digression: power laws
# * Power laws help to describe patterns that are observed in nature, as well human-made phenomena, such as the density of buildings within a city or population density.
#     * Probability distributions: long right tails
#     * Let $c$ denote a constant.  $f(x)=ax^{-k} \Rightarrow f(cx)=a(cx)^{-k} = f(x)\cdot c^{-k} \propto f(x)$.  Therefore, constants are merely scale parameters.
#     * Statistical model: $y_i=ax_i^k+\epsilon_i$ for a sample of $i=(1,...,N)$
#     * Physicists: Everything is linear on a log-log plot.

# %% [markdown]
# ## Digression: compensating differentials (local amenities)
# * There are many local amenities that this model ignores: the High Line or the Tate (Britain or Modern).
#
#
#
# * Many people chose long commute times in exchange for less costly (per unit space) housing.
#
#
#
# * Many people chose short commute times in exchange for high cost (per unit space) housing.
#
#
#
# * The notion of the **compensating differential** is rife in economics.
#     * High risk jobs pay more than low risk jobs (unless there is a **celebrity effect**).
#     * Measuring it is difficult because it requires holding constant the job and letting many different people rotate through.
#     * Working from home?  Suburban co-working?
#
#
#
# * Tim's concern about COVID-19's actual impact on CRE.  It reduces or eliminates compensating differentials

# %% [markdown]
# ## Pizza and beer as they apply to real estate: $c$ and $q$
# * Compensating differentials impact the spatial variation in $p$.
#
#
#
# * This approach consolidates the demand for space in distance, as all income is generated in the CBD.
#     * A type of sorting occurs based on the preferences of people, and as a result transportation becomes criical.
#     * Arguably, the demand for larger space per cost (suburbs) is lower than the demand for CBD space, given commuting cost.
#     * Lower demand in turn depresses the price of housing at locations far from the CBD, causing $p$ to decline as $x$ increases $\Rightarrow$ $p$ and $x$ are inversely related.
#
#
#
#
# * **Graph 6: An Indifference Curve**
#
#
#
# * Basic microeconomics: the indifference curve is the level set of a utility function.
#     * The utility along the entire indifference curve is the same.
#     * What is changing is $p$, the rental price of space.
#
#
#
# * The difference in $c \Rightarrow$ occupying a small dwelling, city living allows consumption of other types of non-space goods, while country living affords space consumption.

# %% [markdown]
# ## Philosophical differences
# * Mathematical model $\rightarrow$ conjectures $\rightarrow$ observations.
#     * Falsification and the development of actual theories, such as relativity.
#
#
#
# * Observation $\rightarrow$ mathematical model $\rightarrow$ conjectures consistent with observation.
#     * Publication and fame.

# %% [markdown]
# ## Model predictions: consistent with observation
# 1. Price per unit space of housing **falls** as the distance to the CBD **rises**.
# 2. Size of dwellings **rises** as the distance to the CBD **rises**.
# 3. Population density **declines** as the distance to the CBD **rises**.

# %% [markdown]
# ## Value of simple math and economics as applied to real estate
# * Urbs and suburbs
# * MF pricing

# %% [markdown]
# ## Income and wealth
# * Increasing income allows for the rise of large dwellings near the CBD.
#     * Billionaires alley in NYC.
#     * Grovensor Square in London.
#     * Remember the basic principle: capital is global but real estate is local.

# %% [markdown]
# ## One-time exogenous increase in population (comparative dynamics as in D-W model)
#
# * Suppose a city is in equilibrium, but experiences a one-time increase in its population.
#
#
#
# * Short run:
#     1. Current housing stock is now too small, leading to excess demand for housing (a housing shortage).
#     2. This excess demand leads to an increase in the price per square foot of housing $p$ everywhere.
#     3. Becasuse housing is now more expensive, consumers choose smaller dwelling sizes, and $q$ falls.
#     4. By raising housing revenue per square foot, the higher price $p$ boosts the profits of dwelling developers, thus driving up land rents.
#
#
#
# * Long run:
#     5. In response to the higher cost of land, developers economize on its use, constructing taller buildings.
#     6. With taller buildings and smaller dwellings, the number of dwellings per unit of land rises.  Hence, population density is larger.
#     7. There is potential expansion of the city boundary.
#
#
#
# * This process is consistent with observation.

# %% [markdown]
# ## An introduction to Pareto efficiency and sources of market failure

# %% [markdown]
# * **Class Discussion**: What does efficiency mean to you?
#
#
#
# * Economists have established a baseline definition of **efficiency**, originally articulated by economist Wilfredo Pareto.
#     * He also articulated the so-called "80-20 rule" with regard to wealth distributions.  80% of the wealth is owed by 20% of a population.  He is also created with a probability distribution, called the **Pareto distribution** to describe the distributions of income and wealth.
#     * The 80-20 rule is a power law consistent with the fractal mathematics of [Benoit Mandelbrot](https://en.wikipedia.org/wiki/Benoit_Mandelbrot).
#
#
#
# * It essentially describes the redistribution of resources (good and services) in an economy.
#
#
#
# * If redistribution can make at least one person better off *without making anyone else worse off*, then such a redistribution is said to be Pareto enhancing or Pareto improving.
#
#
#
# * This process is repeated until at one person must be made worse off to make at least one person better off.
#     * At that point, the equilibrium is said to be *Pareto efficient*.
#     * The set of all points at which this is true is called a *Pareto frontier*.

# %%
from IPython.display import Image
url = 'https://www.assignmentpoint.com/wp-content/uploads/2018/09/production-possibility-frontier.jpg'
Image(url, width=600, height=600)

# %% [markdown]
# * **Class Discussion**: What does market failure mean to you?
#
#
#
# * Given the definition, we can now consider market failure.
#
#
#
# * A market failure is a situation in which the allocation of resources (good and services) is inefficient.
#     * As a result, some action by an external actor to the market can increase welfare through the re-allocation of resources.
#     * If the Pareto inefficient outcome arises in a market without outside intervention, then there is a market failure because at least one market participants could be made better off without making other market participants worse off
#     * The correction of the market failure improves aggregate welfare

# %% [markdown]
# * **Class Discussion**: What does market failure mean to you now?
#
#
#
# * Examples of market failure:
#     * Market power by one or a subset of market participants: You pay my price
#     * Informational asymmetries: I know more than you do about a used car
#     * Externalities: I can affect you in a manner that I can ignore
#
#
#
# * Challenges:
# > "A fundamental problem with the concept of market failure, as economists occasionally recognize, is that it describes a situation that exists everywhere.”  *Tom McCurdy*
#
#
#
# * Philosophical:
#     * Is the cure worse than the disease?  Do the costs outweigh the benefits?  Should there be an approach to measuring outcomes?
#
#
#
# * Legal (but slow):
#     * Antitrust or credbile threat of antitrust
#
#
#
# * Regulatory:
#     * Agencies that address environmental pollution or land use
#
#
#
# * Market design:
#     * Allocation of EM spectrum
#     * Restructure of energy markets

# %% [markdown]
# ## Summary
# * This presentation examines urban spatial structure using a diagrammatic version of the standard urban model.
#
#
#
# * The framework generates realistic intracity predictions, which show that the price per square foot of housing, land rent, building heights, and population density fall moving away from the point mass CBD.
#
#
#
# * In turn, dwelling size increases.
#
#
#
# * The framework also predicts that more populous cities are spatially larger, denser, and more expensive than small cities.

# %% [markdown]
# # Session 4

# %% [markdown]
# ## Class discussion: The Economics of Urban Density
#
# ## Urban sprawl and land use controls
#
# ## Rent control and its potential impact on development

# %% [markdown]
# ## Overview

# %% [markdown]
# * Cities approach land use via zoning quite differently.
#     * Contrast NYC or many large cities in Europe with Houston, Texas.
#     * Arguably rezoning in NYC will be Michael Bloomberg's biggest legacy for NYC by:
#         * Reclaiming waterfront property and developing parks
#         * Rezoning light industry in Brooklyn and Queens for MF development
#
#
#
# * What is a market failure and how might it be measured and then corrected?
#
#
#
# * What are the market failures that land use controls, such as zoning, are meant to correct?

# %% [markdown]
# ## Urban sprawl
#
# * **Class Discussion**: What is a working defintion of the phrase?

# %% [markdown]
# ## Criticisms of "urban sprawl"
# * Long commutes that result from urban expansion create congestion and pollution that are not addressed.
#
#
#
# * Urban expansion consumes land that could be used for open space for the enjoyment of all (positive externality).
#
#
# * Growth at the urban fringe reduces the incentive to redevelop and repurpose land closer to the CBD, hence urban spawl gives rise to center-city blight.
#
#
#
# * Lower density decreases the positive network externalities of interaction and idea sharing.
#
#
#
# * Obesity.
#
#
#
# * Basic evidence of sprawl: spatial growth of cities (size) has exceeded population growth.

# %% [markdown]
# ## City zoning and land use controls
# * In the U.S., a large number of zoning laws, often created by electoral referenda, have arisen in the past 25 years.
#
#
#
# * Conotrols on land use are meant to address sprawl, arguably because sprawl is a market failure.
#     * Limits on the boundaries of cities
#     * Building height restrictions
#     * Zoning to limit development
#
#
#
# * If sprawl is not a market failure, efforts to address sprawl are Pareto inefficient.

# %% [markdown]
# ## Consider the basic model: distance from CBD to the edge of a city
# * Over the long run (or in equilibrium), distance to the CBD rises as the population increases.
#     * This is potentially true as income levels rise, given the demand for space is a normal good.  The larger is our income, the more space we want.
#
#
#
# * The distance to the CBD falls when commuting costs rise (either time or explicit prices).
#
#
#
# * Is there empirical evidence to support these conjectures?
#     * **Table of Elasticities**: Note differences and implications.
#     * Elasticities measure the impact of a percentage change in one variable on the percentage change in another.
#     * Population: Percentage change in city size given a percentage change in in population.  In both studies, this measurement is large.  Commuting costs are negligible in one study, relevant in another.  Income very sizeable in one, and much smaller in another.
#
#
#
# * Nevertheless, empirical evidence **is consistent with model predictions**.
#
#
#
# * Given the magnitudes, it is not suprising to see the growth in urban boundaries in the U.S. over the last 80 years.
#
#
#
# * **Class Discussion**: How does Europe address these issues?

# %% [markdown]
# ## Arguments about the adverse impact of sprawl
# * Arguments have less merit if they arise from benign economic processes rather than market failure.
#
#
#
# * Arguments mave more merit if there are market imperfections or market failures that imply outcomes are not efficient.
#
#
#
# * **Class Discussion**: What are examples of market failures in an urban context?  How might governments correct for them?  Are opportunity zones ("OZs") a method to correct for market failure?

# %% [markdown]
# ## Market failure and urban sprawl
# * We have an operating definition of market failure based on Pareto efficiency.
#
#
#
# * In an urban setting, economists have proposed certain market failures that may drive urban sprawl.
#
#
#
# * There are both positive and negative externalities in this context.
#     * **Positive externalities** of public space called *parks* that might be lost to sprawl.
#     * Because there is no price in a tradeable market for the value of such public space, it may be undersupplied in equilibrium, thus adversely affecting society as a whole.  A benign social planner would increase the amount of space devoted to such public goods.
#         * Yet sprawl, as such, does not appear to encroach on such public space.
#         * Explicit zoning in places like NYC misallocated space into so-called "light industrial".
#         * But the socially-optimal city may consume less physical land but include considerable density (sky scrappers) with substantial open park space.  In the U.S., NYC meets this characterization.
#     * **Negative externalities** from congestion and pollution.
#         * On much firmer ground now.
#         * Urban sprawl creates congestion.  Local government efforts to abate congestion may simply lower the implicit cost of trnaportation, thereby generating additiong sprawl and congestion.  Consider the construction of the Beltway around Washington, D.C.
#         * Consider the congestion charge in London.
#         * Consider the new congestion charge in Manhattan.
#
#
#
# * **Classroom Discussion**: How might density address negative externalities of congestion and pollution?

# %% [markdown]
# ## Congestion
# > "In a world where we do not price roads, time becomes the equilibrating factor..."
# *Tim Savage, PWC's Cities of Opportunity*
#
# > "One of my law partners remarked on the fact that at 4 o’clock, you can’t get a cab..."
# *Ed Koch, The New York Times*
#
#
#
# * Traffic congestion is an example of an externality in an urban setting.
#
#
#
# * The presence of a single extra car on a congested road slows down all the other cars slightly.
#     * Thus increasing the time costs of commuting for all drivers.
#     * In urban areas with bus transportation, even those commuters using public alternatives are affected.
#
#
#
# * For each individual driver, the loss may small.
#     * Aggregating individual losses across large numbers of commuters is a non-trivial dead-weight loss.
#     * But because the individual losses are small, they are ignored (other than horns) by individual commuters.
#
#
#
# * The private cost of commuting, which includes individual time and money costs, is less than the social cost.
#     * This is re-inforced during "rush hours" in major urban centers in the U.S.
#     * **Class Discussion**: Let's evaluate the quotes above.
#
#
#
# * One solution is the creation of congestion pricing through taxation.
#     * Such a mechanism could create a dedicated revenue source for public transportation.
#     * Modern technology allows for the elimination of "toll booths".
#         * London in the 1990's.
#         * NYC in mid-2000's and presently.
#             * NYC is particularly inefficient because bridges and tunnels connecting New York and New Jersey have substantial tolls, while those connecting Manhattan and Queens do not
#             * NYC has also developed a water-based ferry system (expensive) that charges commuters the same price as a subway ride between Midtown and Washington Square (sunk cost)
#         * Singapore.
#         * Stockholm.
#         * Others?

# %% [markdown]
# ## Impact of a congestion tax on urban size
# * Setting aside the mechanism of imposition (tolls or road pricing), let's consider the potential impact of a congestion tax on commuting from the periphery to the CBD.
#
#
#
# * It drives market efficiency because individual commuters must tax account for the additional costs directly.
#     * As a result, the tax increases indidivual costs of transportation and shorter or fewer trips, in equilibrium.
#     * Spatial contraction of the size of the city.
#
#
#
# * This is the theory.
#
#
#
# * Is there an empirical measure of the magnitude of the tax?
#     * In the U.S., 17 cents per mile: Small and Verhoef (2007).
#     * Mathematic modeling of transportation networks also suggests that when appropriate taxes are imposed, urban sprawl declines and density rises: Wheaton (1998) and Brueckner (2007).

# %% [markdown]
# ## Other distortions affecting urban land use
#
# * Local laws and regulations can generate distortions in "optimal" land use.
#     * These are not market failures, but can be summarized by the results of local pressure best summarized by the phrase *nimbyism*: "Not In My Back Yard"-ism.
#     * One arises because of the need to raise revenue to pay for local infrastruture such as sewers or to fund local public education.
#         * For example, extending sewer lines into less densely populated suburbs may be more costly on the margin.
#         * Higher expenses are distributed across all citizens, urban and suburban.
#         * Higher expenses may result in higher tax rates across all citizens, with current residents bearing a disproportionate cost relevant to "new comers".  This constitutes a form of tax subsidy for the new suburban residents.
#         * In response, local governments in the U.S. have begun to impose user (or impact) fees on new residents.  Such fees might also fall on developers when public roads are extended.
#     * In the U.S., however, the larger distortion arises from federal government subsidies of home ownership by allowing the tax deductibility of mortgage interest.
#         * Such subsidies may not drive homeownership, but rather drive larger dwellings per person in equilibrium.  Large houses consume more space and tend to be located in suburbs.
#         * When the U.K. eliminated its mortgage interest subsidies under Thatcher, there was no change in homeownership rates.
#         * **Taxes distort, as do subsidies**.
#     * In the U.S., gasoline taxes are very low relative to Europe and parts of Asia.
#         * This is an implicit subsidy to car ownership and longer and/or more frequent journeys in equilibrium.
#     * In the U.S. and, *especially in Europe*, large subsidies are paid to farmers that consistute a very small fraction of the population or economic output.
#         * Such subsidies **distort land use** and, in equilibrium, place a floor on the price of agricultural land
#
#
#
#
# * Building height and density restrictions.
#     * Washington, D.C. and Cambridge, MA are arguably *aesthetic* incumberances that benefit current occupants with a view to preservation for the future not yet here.
#     * Plausible for Washington, D.C.  Implausible for Cambridge.
#     * In countries with rapid population growth, such as India, height restrictions in Mumbai and Bangalore effectively limit density, perhaps with the idea that density would overwhelm an aging local infrastructure.
#     * Technically, height restrictions represent a limit on a building’s floor area ratio (FAR).
#         * This ratio is equal to the square footage of floor space in the building divided by the lot area.
#         * If a building covers its entire lot, the floor space on each floor would equal the lot area, and an FAR limit of 10 would then restrict the building’s height to 10 stories.  If the building covers half of its lot, the same FAR limit would restrict its height to 20 stories.
#
#
#
# * **Class Discussion**: Other types of regulations distorting land use

# %% [markdown]
# ## Rent control and its potential impact on development
# * Rent control and regulations exist in many U.S. cities, NYC being one of the most famous examples.
#     * **Origin**: wage and price controls imposed in the U.S. during WWII.
#         * These controls essentially created employer-based health insurance in the U.S. as it was not covered (largely because health care involved the use of penicillin).
#         * They also gave rise to regulations governing rents landlords are able to charge tenants in MF
#
#
#
# * In its purest form, a **rent control** is similar to a minimum wage (acting as a ceiling on rents rather than a floor on wages).
#     * It establishes a ceiling on rent levels.
#     * If said ceiling is below an equilibrium rent level, it creates artificial scarsity in equilibrium.
#     * If said ceiling is not sufficient for owners to break even on an NOI basis, investment will not be sufficient to maintain properties.  As a result, *housing quality* will decline over time.
#     * This is the insidious nature of rent control.  Lost of quality is gradual, while the political pressure to enact is immediate, especially in an election cycle in an expensive city like NYC.
#     * Moreover, benefits accrue to *current* tenants, while *future* tenants are receiving lower quality over time.
#         * Gyourko and Linneman (1990) examine data from NYC and find that rent-controlled buildings are more likely to be *dilapidated* than building without rent control.
#
#
#
# * In a weaker form, rent control is called **rent stabilization**.
#     * It controls the rate of growth in rent from some base level.
#     * Many new MF units in NYC are rent stabilized initially and only for a limited period of time after which landlords may charge market rents as well increases that the market will bear.
#
#
#
# * Rent control and a minimum wage.
#     * Rent control is an artificial ceiling on rents.  A minimum wage is an artificial floor on wages.
#         * Empirical studies have demonstrated the adverse impacts of rent control on the quality of existing builings.  Empirical studies have not demonstrated the adverse impacts of minimum wages.
#         * Why?
#         * One argument identifies the nature of housing markets versus labor markets.
#         * In labor markets, employers may have market power which results in equilibrium wages that are lower than would prevail in absence of the employer market power.
#         * In rental markets, for this argument to apply, landlords would have market power, say do to scarcity.  The problem, however, is that, if true, the rent control ceiling *exacerbates this lack of supply* (or its quality).  As a result rent control *increases* landlord market power.
#
#
#
# * Rent control and mobility.
#     * Rent control and public housing are often presented as temporary policies while new stock is built or existing stock is improved.
#     * Arguably, rent control reduces mobility because renters are paying below-market rents, and moving might void this subsidy.
#     * It is also true that public housing has many generations of the same family.
#     * Hence, neither policy has proved to be *temporary*.
#
#
#
# * **Class Discussion**: What are public policies that could assist low income renter in expensive cities?
#     * Direct subsidies?
#     * Expansion of supply?
#     * Other?

# %% [markdown]
# ## Impact on development
#
# * Rent control creates an artificial ceiling on rents.
#
#
#
# * Consider a developer who is focused on new MF development or the refurbishment of an existing building.
#     * We have discussed the use of DCF models to calculate IRRs.
#     * The imposition of the rent ceiling reduces NOI and therefore IRRs.
#     * As a result, rent control negates the profit from construction or redevelopment.
#
#
#
# * We can explore this idea using a simple *stock-flow* model.
#     * Stock is existing housing.
#     * Flow is new construction or redevelopment.
#     * Assume for the sake of argument that all housing is rented rather than owner-occupied.
#     * **Graph 7**.
#         * The left panel is the stock, while the right panel is the flow.
#         * The left panel has an elastic demand curve but an inelastic supply curve that determine the equilibrium rental price, $p$.  For example, $p_0$ is equilibrium rental price for housing stock, $H_0$.
#         * Why inelastic?  **Landlords do not want any vacancy.**
#         * The right panel visualizes flow stock, $S_{\Delta h}$.
#         * Key reflection in the two graphs: When $p$ is high, stock flows are high.  As $p$ falls, so do the flows.  At some price, $p_E$ flow stock is zero, and the market is in equilibrium.
#         * Any rental price below $p_E$ implies a declining stock because flows are negative.
#         * If a rental control law imposes a rental price below $p_E$, housing stock will decline.
#         * If we introduce the idea of quality, there would simply be many different housing markets differented by quality.  In MF, these are A, B and C.  The same logic, however, continues to apply.

# %% [markdown]
# ## Rent control and consensus opinion
# * The broad consensus among economists is that rent control and stabilization policies, while driven by good intention, are examples of policies with adverse unintended consequences.
#     * This is not true of minimum wage laws.
#
#
#
# * They allow local politicians to redirect citizens' ire away from policies that constrain supply toward the development industry.
#     * This perversely provides the development community more market power, even if the media headlines are bad.
#
#
#
# * They allow local politicians to avoid much more important issues regarding the delivery of local public services, such as local school and road quality.
#
#
#
# * High rents in urban locations such as NYC are exacerbated by artificial supply constraints in the face of strong demand.

# %% [markdown]
# ## And this should never have been torn down

# %%
url = 'https://cdn.vox-cdn.com/thumbor/KM2uGSUS96Ka_IJ2S001yNG8DCU=/0x0:3000x2398/1200x0/filters:focal(0x0:3000x2398):no_upscale()/cdn.vox-cdn.com/uploads/chorus_asset/file/9008189/oldpennstation.jpg'
Image(url, width=600, height=600)

# %% [markdown]
# ### Because it might have become this

# %%
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/London_Victoria_station.jpg/440px-London_Victoria_station.jpg'
Image(url, width=600, height=600)

# %% [markdown]
# # Sessions 5 and 6

# %% [markdown]
# ## Positive and negative externalities in the built space

# %% [markdown]
# ### A digression on urban planning in new york city
#
# * NYC has a decidedly mixed track record with formal urban policy.
#     * [Commissioners' Plan of 1811](https://en.wikipedia.org/wiki/Commissioners%27_Plan_of_1811): The grid of Manhattan.
#     * [The creation of Central Park in 1853](https://en.wikipedia.org/wiki/Central_Park): Space preservation with approximately 38 million unique visitors each year (pre-COVID).
#     * [The 1898 unification of the five boroughs](https://en.wikipedia.org/wiki/City_of_Greater_New_York): To create efficiencies in growing city government and infrastructure.
#         * [Bridges](https://en.wikipedia.org/wiki/Brooklyn_Bridge): Brooklyn, Williamsburg and Manhattan Bridges.
#         * [Subways](https://en.wikipedia.org/wiki/IRT_Broadway–Seventh_Avenue_Line): Original IRT, privately developed and owned.  Also called the 7th Avenue line (1, 2, 3)
#         * [Trains](https://en.wikipedia.org/wiki/Grand_Central_Terminal): Grand Central Terminal and Pennsylvania Station.
#     * [The arrival of the House of Morgan from London in early 1900's](https://www.amazon.com/House-Morgan-American-Banking-Dynasty/dp/0802144659): Despite the lack of central banking in the U.S.
#         * [The corner of Wall and Broad Streets](https://www.amazon.com/House-Morgan-American-Banking-Dynasty/dp/0802144659): Creation of modern banking centers and money markets.
#     * [Immigration and sanitation](https://en.wikipedia.org/wiki/Lower_East_Side_Tenement_Museum): Visit the Tenement Museum.
#     * [Robert Moses](https://en.wikipedia.org/wiki/Robert_Moses)

# %% [markdown]
# ## The provision of local public goods (amenities)
#
# * In the U.S. and Europe, local municipalities provide the bulk of local public goods.
#     * Elementary and secondary education
#     * Police and fire protection
#     * Mass transit and city streets
#     * Recreational facilities
#     * Sewers and sanitation
#
# * Arguably, these goods play a bigger role in people’s daily lives than the goods provided by higher levels of government, such as national defense or courts.
# * *Tiebout hypothesis* (1956): People can move among different local governments to obtain the mix of taxation and services that meet their needs.
#     * **Voting with your feet**.
#     * First best outcome: Benign omnipotent economist and observer of all public needs who is capable of maximizing social welfare (as the sum of individual welfare).
#     * Second best: Voting with your feet.
#     * **Police example**.

# %% [markdown]
# ### Majority voting
#
# * Benign omnipotent economist determines the provision of public goods based on observation.
# * In reality, in the U.S. and Europe, local voting and elections serve the function of clearing the market.
#     * Three citizens vote and share the costs, say equally, through a flat fee.
#     * Note that each citizen would like the other two to pay for the public good because once a policeman has been hired, each citizen still benefits.
#         * [Public good characteristics](https://en.wikipedia.org/wiki/Public_good)
#     * Voting is a method to aggregate preferences, but it may not lead to an optimal outcome if voter preferences are highly differentiated.
#         * Consider Amazon's effort to locate H2Q in Queens.  It generated negative reactions from politicians without much stated opposition from actual residents.
#         * Consider the Bloomberg congestion pricing plan that entailed placing a charge on the East River bridges.  It generated considerable adverse residential reaction in Brooklyn and Queens as well as considerable opposition from local politicians there.
#     * If voter preferences cannot be aggregated using a local voting mechanism, and there is not benign omnipotent economist available to aggregate prefences, allow individuals to vote with their feet can give rise to the provision of public goods that better match diffuse (or differentiated) preferences.
#         * Consider U.S. states.
#         * Consider the European Union, which is said to have a democracy "deficit".

# %% [markdown]
# ### Voting with ones feet in the face of property taxation
# * In the U.S., local governments are financed largely by property taxes and local sales taxes.
# * In Europe, ?
# * Property taxes in the U.S. are an **assessed levy** that reflects the **value of a house**.  To the extent that house size and income are positively correlated, the assessment is a proxy for an income tax.
#     * Fundamentally different than a flat tax per person (or per capita).
# * To the extent that higher revenue areas are driven by property taxes, and the higher revenue results in larger provision of public goods, low income people have a potential interest in moving into high income neighborhoods.
#     * Again, it the basic idea of a public good: once it has been provided, I cannot be deprived of consuming it, and I cannot exclude you from consuming it.
#     * Minimal lot size restrictions.

# %% [markdown]
# ### Voting with ones feet and the impact on sprawl
#
# * Recall space is a normal good, and the demand for it rises as income rises.
# * Voting with one's feet in the U.S. has led to an incentive for wealthy to leave the CBD.
#     * Given local taxes are proportional to income taxes, wealthy have an incentive move from the CBD to the suburbs.
#     * The wealthy may move away from the CBD, creating potential problems in funding local government and the provision of local public goods.
#         * Central funding from national governments.
#         * A microcosm of the European Union?
#         * Other?
#             * Maintain substantial local public goods: Paris public schools.
#             * Public-private partnerships to create local public goods such as the High Line in NYC.
#             * Quasi-governmental entities such the NYC Economic Development Corporation (NYCEDC) to facilitate community involvement as well as real estate and economic development.

# %% [markdown]
# ## Positive externalities
# * Economics and the benefits that accrue to firms and workers.
# * Social networks
# * Public space, such as parks
#     * Local and national governments, on balance, subsidize these activities, which increases social welfare.
#     * Despite broad complaints.

# %% [markdown]
# ## Negative externalities
#
# ### Congestion
# * Discussed at length above.

# %% [markdown]
# ### Pollution
#
# * Urban density is typically associated with greater economic efficiency.
# * Pollution has reduced quality of life and health in urban centers, particularly during the Industrial Revolution.
#     * Westminster Abbey in London before and after restoration.

# %%
# Before

url = 'http://i.imgur.com/HW17iWd.jpg'
Image(url, width=300, height=300)

# %%
# After

url = 'https://pbs.twimg.com/profile_images/1082940029356392448/KQBxRvB3.jpg'
Image(url, width=300, height=300)

# %%
# The London Fog of 1952.

url = 'https://i.kinja-img.com/gawker-media/image/upload/s--TeyL8G-6--/c_fit,f_auto,fl_progressive,q_80,w_636/kvj8zrwbuvzabl8wfrm1.jpg'
Image(url, width=300, height=300)

# %%
# New Delhi, India today.

url = 'http://www.brownpoliticalreview.org/wp-content/uploads/2017/03/BN-QO270_indpol_J_20161101015524-897x494.jpg'
Image(url, width=300, height=300)

# %%
# Beijing, China today.

url = 'https://cdn.cnn.com/cnnnext/dam/assets/170504022201-02-beijing-sand-storms-0504-large-169.jpg'
Image(url, width=300, height=300)

# %%
# Mexico City, Mexico today.

url = 'https://mk0mexiconewsdam2uje.kinstacdn.com/wp-content/uploads/2019/05/pollution-1.jpg'
Image(url, width=300, height=300)

# %%
# Los Angeles, U.S. today.

url = 'https://www.sciencenews.org/wp-content/uploads/2018/02/021418_LH_air-pollution_feat.jpg'
Image(url, width=300, height=300)

# %% [markdown]
# ### Pollution and crime: negative externalities in the urban built space
# ### Application of pigouvian taxation
#
# #### Digression on microeconomics
# * A **marginal benefit** curve is a measure of the incremental benefit of the incremental increase in *something*.
# * A **marginal cost** curve is a measure of the incremental cost of the incremental increase in *something*.
# * How to determine the optimal level of *something*?  Apply the following rule.
#     * Increase the level of *something* as long as the marginal benefit outweighs the marginal cost.
#     * The difference between the two is the marginal gain (or loss) of *something*.
#     * For firms in a competitive market, this rule gives rise to "equating marginal revenue with marginal cost".
#     * For individuals who take prices as given, this rule gives rise to "equating the ratio of marginal utility to the ratio of prices."
#     * In finance, it also gives rise to the CAPM per Lucas (1978).

# %% [markdown]
# ### Basic framework
#
# * Consider three houses and a single polluting source.
# * Pollution creates small particulate matter that can harm health, as well as adversely impact the value of housing.
#     * Large literature to measure the magnitude: See Chay and Greenstone (2005) and its update, Berkman, Hubbard and Savage (2011).
#     * Adverse impacts are not small $\Rightarrow$ enforcement benefits are large.  Tougher enforcement of U.S. air-quality standards over the 1970s generated an aggregate property-value increase of 45 billion.
#
# Brueckner, Jan K.. Lectures on Urban Economics (The MIT Press) (p. 206). The MIT Press. Kindle Edition.
# * **Graphs 8 and 9**
#     * Let $D(p)$ be a measure of damage done by pollution, $p$.
#     * Let $D^\prime(p)$ be positive in $p$.
#     * Pollution is harmful the for residents, but necessary (and therefore beneficial) for the firm.
#         * $B(p)$ and $B^\prime(p)$ measure the benefit and marginal (or incremental) benefit to the firm.
#         * At $\overline{p}$, no pollution abatement occurs.  Small increases in abatement are inexpensive for the firm.
#     * There is no marketplace for pollution abatement.
#
# * Basic Coasian principle: residents could pay firm not to pollute or firm could pay residents to compensate them for the pollution.  Either approach is, from economics, indistinguisable.

# %% [markdown]
# ### Socially-optimal pollution
#
# * It is not zero, but because there is no market with transparent prices, the amount of abatement is not socially optimal.
# * In absence of controls, the firm would pollute up to the point that the marginal benefit from doing so is zero or $B^\prime(p) = 0$.
#     * The marginal benefit and damage curves allow us to expore the socially-optimal level of pollution.
# * **Graph 10**
#     * Apply the rule from above.
#     * Start at no pollution, $p=0$, and increase the level of pollution as long as the marginal benefit exceeds the marginal damage.
#     * Stop when they are equal.
#
# #### Getting to $p^*$
# * Coasian negotiation between firm and residents.
#     * Transactions cost must be low, and no party should have bargaining power.
#     * Property rights must be assigned: someone must "own the air".
#         * Firm has the right to pollute, and residents pay the firm not to pollute.  (Good luck with that.)
#         * Residents have the right to clear air.  Residents through government are compensated for losses by the firm.
# * Government mandates, such as the Clear Air Act in the U.S.
# * Government uses Pigouvian tax.  [A.C. Pigou](https://en.wikipedia.org/wiki/Arthur_Cecil_Pigou).  The tax forces the firm to internalize the costs of pollution as captured by the marginal damage curve.  This is the basis for carbon taxes.
#     * Government creates a market that **could not** form on its own.  This was called "Cap and Trade" in the U.S.
#         * Establish an overall cap on the level of carbon and create tradeable permits.  The least efficient firms will pay for the permits, and the most efficient will sell the permits.  This forces the least efficient firms to internalize the costs of pollution.
#             * This was the basis for the [1990 Clear Air Act](https://environmentallaw.uslegal.com/federal-laws/clean-air-act/).
#     * Auction markets for EM spectrum have been incredibly successful.
#     * Auction markets for energy have been much less successful, at least in the U.S.

# %% [markdown]
# ## Crime

# %%
url = 'https://cdn.factcheck.org/UploadedFiles/2016/07/Violent-Crime-Rate-Chart1.png'
Image(url, width=600, height=600)

# %%
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0c/NYC_murders2.png/500px-NYC_murders2.png'
Image(url, width=800, height=800)

# %% [markdown]
# ### This is a very murky subject
# * Subject to different reporting standards both in the U.S. and internationally.
#     * [Hidden figure of crime](https://en.wikipedia.org/wiki/Dark_figure_of_crime).
#
#
#
# * The U.S. is **a very violent country** by OECD standards.
#
#
#
# * Crime in not an urban phenomenon.
#     * In the U.S., it did not arise with urbanization.
#     * The role of lead as a neuro-toxin. [Good summary](https://www.motherjones.com/kevin-drum/2018/02/an-updated-lead-crime-roundup-for-2018/).  Let's review.

# %% [markdown]
# ### A toy model (Blecker and Glaeser)
#
# * Criminality is an occupational choice, like any choice of occupation.
#
#
#
# * As such, there are benefits and costs.
#     * Benefits: Outsized returns on effort.
#     * Costs: Getting caught and successfully prosecuted.

# %% [markdown]
# ### Basic framework
#
# * Let NYC have $n$ residents, indexed by $n=1, 2, 3, ..., \overline{n}$.
#     * Residents are differentiated by skill, income and education levels.
#     * For ease, we sort on legal income.
#     * **Graphs 11 and 12**
#     * Now suppose while legal income varies, each resident is equally skilled at illegal income, which grants them some value, $L$, which implies there will be $n_L$ criminals and a crime incidence of $\frac{n_L}{\overline{n}}$.
#     * Obviously, absent any cost, criminal incidence is rising in $L$.
# * Crime and punishment.
#     * As the result of apprehension and prosection, some fraction $\alpha$ of $n_L$ are jailed and forfeit their illegal income.
#     * Obviously, $\alpha$ depends on several things, include the ability to observe, apprehend and prosecute.
#
#
#
#
# * Drivers to consider:
#     1. Education, which changes the slope.  (See **Graph 13**.)
#     2. Enforcement.  (See **Graph 14**.)
#     3. Varying levels of $L$, giving rise to spatial concentrations of crime.
#         * Crime "congeston" as criminals compete for a fixed $L$ locally.
#         * As a result, criminal income per criminal will tend to be lower when there are more criminals.

# %% [markdown]
# # Midterm Review
